# %% [markdown]
# Data cleaning

# %% [markdown]
# Step 1: Importing Necessary Libraries

# %% [markdown]
# - No duplicates
# - No blank spaces (ex: `" I love python "` => `"I love python"`)
# - No errors
# - No empty values

# %%
import pandas as pd
import json
import csv
import numpy as np

# %% [markdown]
# Step 2: Reading Data into a DataFrame

# %%
df = pd.read_json('final_dataset.json')
df = df.replace(r'\s+', '', regex=True)
df
# Out:
#                                                       Url  Openfire  \
# 2       https://www.immoweb.be/en/classified/house/for...     False
# 6       https://www.immoweb.be/en/classified/apartment...     False
# 8       https://www.immoweb.be/en/classified/house/for...     False
# 10      https://www.immoweb.be/en/classified/house/for...     False
# 13      https://www.immoweb.be/en/classified/house/for...     False
# ...                                                   ...       ...
# 176860  https://www.immoweb.be/en/classified/apartment...     False
# 176890  https://www.immoweb.be/en/classified/apartment...     False
# 176903  https://www.immoweb.be/en/classified/apartment...     False
# 176904  https://www.immoweb.be/en/classified/house/for...     False
# 176905  https://www.immoweb.be/en/classified/apartment...     False
#
#         Furnished  Terrace  Garden  PropertyId  TypeOfProperty  PostalCode  \
# 2           False     True   False     8720603               1        9140
# 6            True    False   False     8719883               2        1050
# 8           False    False   False    10760048               1        2840
# 10          False     True   False    10759911               1        3740
# 13          False     True   False    10759812               2        8851
# ...           ...      ...     ...         ...             ...         ...
# 176860      False     True   False     8727283               2        3800
# 176890      False    False   False     8724542               2        6760
# 176903      False     True   False    20014272               2        2200
# 176904      False    False   False    10877172               1        9450
# 176905      False     True   False    10718231               2        4600
#
#        SubtypeOfProperty  TypeOfSale  ...        Kitchen StateOfBuilding  \
# 2                  house           1  ...      installed   justrenovated
# 6             flatstudio           2  ...  hyperequipped   justrenovated
# 8                  house           1  ...           None            None
# 10                 house           1  ...           None            good
# 13             houseunit           1  ...           None            None
# ...                  ...         ...  ...            ...             ...
# 176860         apartment           1  ...   semiequipped      torenovate
# 176890         apartment           2  ...      installed           asnew
# 176903       groundfloor           1  ...   semiequipped            None
# 176904           mansion           1  ...           None      torenovate
# 176905     apartmentunit           1  ...      installed            None
#
#         Heating Bedrooms  SurfaceOfGood  SwimmingPool  ConstructionYear  \
# 2           gas        3           60.0         False            1940.0
# 6           gas        8            NaN         False               NaN
# 8          None        3          158.0         False            2024.0
# 10         None        3          337.0         False            2023.0
# 13         None        3          267.0         False               NaN
# ...         ...      ...            ...           ...               ...
# 176860      gas        2            NaN         False            1967.0
# 176890  fueloil        2            NaN         False            2015.0
# 176903     None        1            NaN         False            2023.0
# 176904     None        4          338.0         False            1910.0
# 176905      gas        2            NaN         False            2024.0
#
#         GardenArea  LivingArea  NumberOfFacades
# 2              NaN       116.0              2.0
# 6              NaN       312.0              NaN
# 8              NaN       150.0              2.0
# 10             NaN       138.0              3.0
# 13             NaN         NaN              3.0
# ...            ...         ...              ...
# 176860         NaN       135.0              2.0
# 176890         NaN        90.0              2.0
# 176903         NaN        52.0              2.0
# 176904         NaN       280.0              NaN
# 176905         NaN       101.0              3.0
#
# [115070 rows x 21 columns]

# %% [markdown]
# Step 3: Exploring the DataFrame

# %%
print(df.shape)
print(df.info())
print(df.describe())
# Out:
# (115070, 21)
# <class 'pandas.core.frame.DataFrame'>
# Index: 115070 entries, 2 to 176905
# Data columns (total 21 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Url                115070 non-null  object
#  1   Openfire           115070 non-null  bool
#  2   Furnished          115070 non-null  bool
#  3   Terrace            115070 non-null  bool
#  4   Garden             115070 non-null  bool
#  5   PropertyId         115070 non-null  int64
#  6   TypeOfProperty     115070 non-null  int64
#  7   PostalCode         115070 non-null  int64
#  8   SubtypeOfProperty  115070 non-null  object
#  9   TypeOfSale         115070 non-null  int64
#  10  Price              115070 non-null  int64
#  11  Kitchen            64857 non-null   object
#  12  StateOfBuilding    78622 non-null   object
#  13  Heating            65283 non-null   object
#  14  Bedrooms           115070 non-null  int64
#  15  SurfaceOfGood      56247 non-null   float64
#  16  SwimmingPool       115070 non-null  bool
#  17  ConstructionYear   66671 non-null   float64
#  18  GardenArea         21624 non-null   float64
#  19  LivingArea         101377 non-null  float64
#  20  NumberOfFacades    74262 non-null   float64
# dtypes: bool(5), float64(5), int64(6), object(5)
# memory usage: 15.5+ MB
# None
#          PropertyId  TypeOfProperty     PostalCode     TypeOfSale  \
# count  1.150700e+05   115070.000000  115070.000000  115070.000000
# mean   1.207064e+07        1.563718    5150.751238       1.109420
# std    2.700473e+06        0.495926    3056.452193       0.312167
# min    1.838035e+06        1.000000       0.000000       1.000000
# 25%    1.112492e+07        1.000000    2250.000000       1.000000
# 50%    1.136506e+07        2.000000    4624.000000       1.000000
# 75%    1.145717e+07        2.000000    8400.000000       1.000000
# max    2.001911e+07        2.000000   10000.000000       2.000000
#
#               Price       Bedrooms  SurfaceOfGood  ConstructionYear  \
# count  1.150700e+05  115070.000000   5.624700e+04      66671.000000
# mean   3.843611e+05       2.706822   3.211810e+03       1987.786009
# std    4.947272e+05       1.869244   4.860183e+05         47.447747
# min    1.000000e+00       0.000000   0.000000e+00       1753.000000
# 25%    2.050000e+05       2.000000   1.500000e+02       1964.000000
# 50%    3.100000e+05       3.000000   3.550000e+02       2001.000000
# 75%    4.390000e+05       3.000000   8.060000e+02       2023.000000
# max    3.500000e+07     200.000000   1.152500e+08       8071.000000
#
#          GardenArea     LivingArea  NumberOfFacades
# count  2.162400e+04  101377.000000     74262.000000
# mean   4.691081e+04     167.543240         2.792438
# std    6.800359e+06    1842.644114         0.872616
# min    1.000000e+00       9.000000         1.000000
# 25%    4.800000e+01      90.000000         2.000000
# 50%    1.400000e+02     124.000000         3.000000
# 75%    4.500000e+02     181.000000         4.000000
# max    1.000000e+09  452230.000000        24.000000

# %% [markdown]
# Step 4: Data Cleaning and Preprocessing

# %% [markdown]
# checking for duplicates

# %%
df.drop_duplicates()
# Out:
#                                                       Url  Openfire  \
# 2       https://www.immoweb.be/en/classified/house/for...     False
# 6       https://www.immoweb.be/en/classified/apartment...     False
# 8       https://www.immoweb.be/en/classified/house/for...     False
# 10      https://www.immoweb.be/en/classified/house/for...     False
# 13      https://www.immoweb.be/en/classified/house/for...     False
# ...                                                   ...       ...
# 176860  https://www.immoweb.be/en/classified/apartment...     False
# 176890  https://www.immoweb.be/en/classified/apartment...     False
# 176903  https://www.immoweb.be/en/classified/apartment...     False
# 176904  https://www.immoweb.be/en/classified/house/for...     False
# 176905  https://www.immoweb.be/en/classified/apartment...     False
#
#         Furnished  Terrace  Garden  PropertyId  TypeOfProperty  PostalCode  \
# 2           False     True   False     8720603               1        9140
# 6            True    False   False     8719883               2        1050
# 8           False    False   False    10760048               1        2840
# 10          False     True   False    10759911               1        3740
# 13          False     True   False    10759812               2        8851
# ...           ...      ...     ...         ...             ...         ...
# 176860      False     True   False     8727283               2        3800
# 176890      False    False   False     8724542               2        6760
# 176903      False     True   False    20014272               2        2200
# 176904      False    False   False    10877172               1        9450
# 176905      False     True   False    10718231               2        4600
#
#        SubtypeOfProperty  TypeOfSale  ...        Kitchen StateOfBuilding  \
# 2                  house           1  ...      installed   justrenovated
# 6             flatstudio           2  ...  hyperequipped   justrenovated
# 8                  house           1  ...           None            None
# 10                 house           1  ...           None            good
# 13             houseunit           1  ...           None            None
# ...                  ...         ...  ...            ...             ...
# 176860         apartment           1  ...   semiequipped      torenovate
# 176890         apartment           2  ...      installed           asnew
# 176903       groundfloor           1  ...   semiequipped            None
# 176904           mansion           1  ...           None      torenovate
# 176905     apartmentunit           1  ...      installed            None
#
#         Heating Bedrooms  SurfaceOfGood  SwimmingPool  ConstructionYear  \
# 2           gas        3           60.0         False            1940.0
# 6           gas        8            NaN         False               NaN
# 8          None        3          158.0         False            2024.0
# 10         None        3          337.0         False            2023.0
# 13         None        3          267.0         False               NaN
# ...         ...      ...            ...           ...               ...
# 176860      gas        2            NaN         False            1967.0
# 176890  fueloil        2            NaN         False            2015.0
# 176903     None        1            NaN         False            2023.0
# 176904     None        4          338.0         False            1910.0
# 176905      gas        2            NaN         False            2024.0
#
#         GardenArea  LivingArea  NumberOfFacades
# 2              NaN       116.0              2.0
# 6              NaN       312.0              NaN
# 8              NaN       150.0              2.0
# 10             NaN       138.0              3.0
# 13             NaN         NaN              3.0
# ...            ...         ...              ...
# 176860         NaN       135.0              2.0
# 176890         NaN        90.0              2.0
# 176903         NaN        52.0              2.0
# 176904         NaN       280.0              NaN
# 176905         NaN       101.0              3.0
#
# [115070 rows x 21 columns]

# %% [markdown]
# checking for empty values

# %%
df_cleaned = df.dropna()

df_cleaned
# Out:
#                                                       Url  Openfire  \
# 131     https://www.immoweb.be/en/classified/house/for...     False
# 467     https://www.immoweb.be/en/classified/house/for...     False
# 589     https://www.immoweb.be/en/classified/house/for...     False
# 610     https://www.immoweb.be/en/classified/house/for...     False
# 664     https://www.immoweb.be/en/classified/house/for...     False
# ...                                                   ...       ...
# 171769  https://www.immoweb.be/en/classified/house/for...     False
# 174674  https://www.immoweb.be/en/classified/house/for...     False
# 174936  https://www.immoweb.be/en/classified/house/for...     False
# 175410  https://www.immoweb.be/en/classified/house/for...     False
# 175608  https://www.immoweb.be/en/classified/house/for...     False
#
#         Furnished  Terrace  Garden  PropertyId  TypeOfProperty  PostalCode  \
# 131         False     True    True    10757487               1        1330
# 467         False     True    True    10749840               2        9550
# 589         False     True    True    10747901               1        4630
# 610         False     True    True    10747198               1        1755
# 664         False     True    True    10745947               1        1560
# ...           ...      ...     ...         ...             ...         ...
# 171769      False     True    True     9316562               1        6061
# 174674      False    False    True     9033044               1        7000
# 174936      False     True    True     9002845               1        6020
# 175410      False     True    True     8942923               1        1640
# 175608      False     True    True     8916587               1        1410
#
#           SubtypeOfProperty  TypeOfSale  ...           Kitchen  \
# 131                   house           1  ...     hyperequipped
# 467           townhouseunit           1  ...         installed
# 589                   villa           1  ...         installed
# 610                   house           1  ...         installed
# 664                   house           1  ...      semiequipped
# ...                     ...         ...  ...               ...
# 171769                house           1  ...      semiequipped
# 174674              mansion           2  ...     hyperequipped
# 174936                house           1  ...      semiequipped
# 175410  exceptionalproperty           2  ...  usahyperequipped
# 175608                villa           2  ...  usahyperequipped
#
#        StateOfBuilding  Heating Bedrooms  SurfaceOfGood  SwimmingPool  \
# 131      justrenovated      gas        3          348.0         False
# 467               good      gas        3          241.0         False
# 589               good  fueloil        4         1980.0         False
# 610         torenovate  fueloil        3          433.0         False
# 664         torenovate  fueloil        5          345.0         False
# ...                ...      ...      ...            ...           ...
# 171769      tobedoneup      gas        3          644.0         False
# 174674            good  fueloil        4         4000.0         False
# 174936            good  fueloil        3          155.0         False
# 175410           asnew      gas        6         4000.0         False
# 175608           asnew      gas        5          970.0         False
#
#         ConstructionYear  GardenArea  LivingArea  NumberOfFacades
# 131               1930.0       348.0       152.0              3.0
# 467               2023.0       178.0       132.0              3.0
# 589               1977.0      1850.0       147.0              4.0
# 610               1962.0       220.0       120.0              4.0
# 664               1918.0       345.0       216.0              3.0
# ...                  ...         ...         ...              ...
# 171769            1900.0       300.0       115.0              3.0
# 174674            1935.0      3700.0       300.0              4.0
# 174936            1900.0        59.0       133.0              2.0
# 175410            2013.0         1.0       634.0              4.0
# 175608            2005.0         1.0       275.0              4.0
#
# [5383 rows x 21 columns]

# %%
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5383 entries, 131 to 175608
# Data columns (total 21 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Url                5383 non-null   object
#  1   Openfire           5383 non-null   bool
#  2   Furnished          5383 non-null   bool
#  3   Terrace            5383 non-null   bool
#  4   Garden             5383 non-null   bool
#  5   PropertyId         5383 non-null   int64
#  6   TypeOfProperty     5383 non-null   int64
#  7   PostalCode         5383 non-null   int64
#  8   SubtypeOfProperty  5383 non-null   object
#  9   TypeOfSale         5383 non-null   int64
#  10  Price              5383 non-null   int64
#  11  Kitchen            5383 non-null   object
#  12  StateOfBuilding    5383 non-null   object
#  13  Heating            5383 non-null   object
#  14  Bedrooms           5383 non-null   int64
#  15  SurfaceOfGood      5383 non-null   float64
#  16  SwimmingPool       5383 non-null   bool
#  17  ConstructionYear   5383 non-null   float64
#  18  GardenArea         5383 non-null   float64
#  19  LivingArea         5383 non-null   float64
#  20  NumberOfFacades    5383 non-null   float64
# dtypes: bool(5), float64(5), int64(6), object(5)
# memory usage: 741.2+ KB
